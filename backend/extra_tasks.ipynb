# %%
from opensearchpy import OpenSearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import boto3
from dotenv import load_dotenv
import os

load_dotenv()

aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')
aws_session_token = os.getenv('AWS_SESSION_TOKEN')
region = os.getenv('AWS_REGION', 'us-east-1')

print(aws_access_key_id)
print(aws_secret_access_key)
print(aws_session_token)
print(region)

session_kwargs = {'region_name': region}
if aws_access_key_id and aws_secret_access_key:
    session_kwargs['aws_access_key_id'] = aws_access_key_id
    session_kwargs['aws_secret_access_key'] = aws_secret_access_key
if aws_session_token:
    session_kwargs['aws_session_token'] = aws_session_token
    
session = boto3.Session(**session_kwargs)
credentials = session.get_credentials()

awsauth = AWS4Auth(
    credentials.access_key,
    credentials.secret_key,
    'us-east-1',
    'aoss',
    session_token=credentials.token
)

client = OpenSearch(
    hosts=[{'host': os.getenv('OPENSEARCH_SERVERLESS_HOST').replace('https://', '').replace('http://', '').strip(), 'port': 443}],
    http_auth=awsauth,
    use_ssl=True,
    verify_certs=True,
    connection_class=RequestsHttpConnection
)

# Get all documents for the video
search_body = {
    "query": {
        "term": {
            "video_id": "4d9d5b27-bc36-40f6-bcd1-d7939a28e372"
        }
    },
    "size": 100,
    "_source": ["video_id", "timestamp_start", "timestamp_end", "embedding_scope"]
}

results = client.search(index="video_clips", body=search_body)

print(results)


# Update each document
for hit in results['hits']['hits']:
    doc_id = hit['_id']
    timestamp_start = hit['_source']['timestamp_start']
    
    # Update with new clip_text
    client.update(
        index="video_clips",
        id=doc_id,
        body={
            "doc": {
                "clip_text": f"City Nightlife: Buildings and Road lighted up in night"
            }
        }
    )
    print(f"Updated {doc_id}")

print("Done!")
# Out:
# ASIA5XF5XSWV4DVBXMNO
# dGoy8u+vUONbzMKtfRJD3HbVDOaUcJwFQeOL1npQ
# ...
# us-east-1
# {'took': 23, 'timed_out': False, '_shards': {'total': 0, 'successful': 0, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 16, 'relation': 'eq'}, 'max_score': 3.1520784, 'hits': [{'_index': 'video_clips', '_id': '1%3A0%3Awoxp4pkB1tgzjRCFM323', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-text', 'timestamp_end': 6.800000190734863, 'video_id': '4d9d5b27-bc36-40f6-bcd1-d7939a28e372', 'timestamp_start': 0.0}}, {'_index': 'video_clips', '_id': '1%3A0%3Axoxp4pkB1tgzjRCFOX19', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-text', 'timestamp_end': 34.0, 'video_id': '4d9d5b27-bc36-40f6-bcd1-d7939a28e372', 'timestamp_start': 27.200000762939453}}, {'_index': 'video_clips', '_id': '1%3A0%3AyYxp4pkB1tgzjRCFPX27', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-text', 'timestamp_end': 54.10000228881836, 'video_id': '4d9d5b27-bc36-40f6-bcd1-d7939a28e372', 'timestamp_start': 47.400001525878906}}, {'_index': 'video_clips', '_id': '1%3A0%3Ay4xp4pkB1tgzjRCFQH1p', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-image', 'timestamp_end': 13.600000381469727, 'video_id': '4d9d5b27-bc36-40f6-bcd1-d7939a28e372', 'timestamp_start': 6.800000190734863}}, {'_index': 'video_clips', '_id': '1%3A0%3AzYxp4pkB1tgzjRCFQ308', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-image', 'timestamp_end': 27.200000762939453, 'video_id': '4d9d5b27-bc36-40f6-bcd1-d7939a28e372', 'timestamp_start': 20.400001525878906}}, {'_index': 'video_clips', '_id': '1%3A0%3Az4xp4pkB1tgzjRCFRn1o', '_score': 3.1520784, '_source': {'embedding_scope': 'visual-image', 'timestamp_end':